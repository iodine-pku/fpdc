# %%
from matplotlib import pyplot as plt

# %%
x = ['1','2','4','8','16','32','64','128','256','512','1024']
y = [3.5*10**3,1.77*10**3,884,443,223,113,64.2,64.1,64,64.1,64.3]
plt.bar(x,y)
plt.xlabel('threads in block')
plt.ylabel('copy kernel time: in µs')
# Out:
# Text(0, 0.5, 'copy kernel time: in µs')

# %%
x = ['1d','3d']
y = [64,338]
plt.bar(x,y)
plt.xlabel('dimension of block')
plt.ylabel('copy kernel time: in µs')
# Out:
# Text(0, 0.5, 'copy kernel time: in µs')

# %%
x = ['(8,8,8)','(4,8,8)','(16,8,8)','(4,4,4)']
y = [828,812,919,901]
plt.ylim([700,1000])
plt.bar(x,y)
plt.xlabel('shape of block')
plt.ylabel('spmv time: in µs')
# Out:
# Text(0, 0.5, 'spmv time: in µs')

# %%
# Data to be plotted
labels = ['memory allocation time', 'data transfer time', 'kernel time(include register-global transfer)']
sizes = [0.0244211630006248, 0.007241348000206926, 0.1790220609982498]

# Plotting the pie chart
plt.pie(sizes, labels=labels,normalize=True)
plt.show()

# %%
# Data to be plotted
labels = ['cpu alloc', 'gpu alloc']
sizes = [0.013281465000545722,  0.001474357000006421]

# Plotting the pie chart
plt.pie(sizes, labels=labels,normalize=True)
plt.show()

# %%
(0.20324681499994313-0.185)/0.20324681499994313*100
# Out:
# 8.977663438390527
